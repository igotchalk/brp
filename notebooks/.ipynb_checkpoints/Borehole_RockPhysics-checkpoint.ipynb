# %% [markdown]
# # Borehole rock-physics
# ## Investigating the accuracy of various rock-physics transforms using borehole data

# %%
from pathlib import Path
import os
import sys
import numpy as np
from matplotlib import pyplot as plt
import lasio
import pandas as pd

# %%
workdir = Path('../')
lasdir = workdir.joinpath('las_logs')
auxdir=  workdir.joinpath('data','auxiliary')
mw8_fres_fname = 'mw8_fres.las'
mw8_tmp_fname = 'mw8_tmp.las'
mw8_all_fname = 'MW-8D.las'

mw8_all  = lasio.read(lasdir.joinpath(mw8_all_fname).as_posix())
mw8_fres = lasio.read(lasdir.joinpath(mw8_fres_fname).as_posix())
mw8_tmp  = lasio.read(lasdir.joinpath(mw8_tmp_fname).as_posix())

# %%
fres_dept = mw8_fres['DEPT']
mw8_dept = mw8_all['DEPT']
fres_halffoot = mw8_fres['FRES'][ mw8_fres['DEPT']%0.5==0]
fres_halffoot[fres_halffoot < 0] =.001
fres_dept_halffoot = fres_dept[ mw8_fres['DEPT']%0.5==0]

#find indicies in the mw8 log that match the fres log
fresdept2mw8dept = [np.where(ind==mw8_dept)[0] for ind in list(fres_dept_halffoot)]
fresdept2mw8dept = np.r_[[np.asscalar(ind) if len(ind)==1 else np.nan for ind in fresdept2mw8dept]]
mask = ~np.isnan(fresdept2mw8dept)


#Mask out nan values
fresdept2mw8deptma = fresdept2mw8dept[mask].astype('int32')
fres_halffootma = fres_halffoot[mask]
mw8_tmpma = mw8_tmp['TMP'][mask]
# Out:
# /Users/ianpg/anaconda/envs/SWIenv/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in less
#   after removing the cwd from sys.path.

# %%
mw8_fres_data = np.ones(len(mw8_dept))*-999.25
mw8_tmp_data = np.ones(len(mw8_dept))*-999.25

mw8_fres_data[mw8_fres_data==-999.25]  = np.nan
mw8_fres_data[fresdept2mw8deptma] = fres_halffootma

mw8_tmp_data[mw8_tmp_data==-999.25]  = np.nan
mw8_tmp_data[fresdept2mw8deptma] = mw8_tmpma

#Add the curve and export to csv
mw8_all.add_curve('FRES', mw8_fres_data, unit='OHMM')
mw8_all.add_curve('TMP', mw8_tmp_data, unit='DEGF')

mw8_all.to_csv(lasdir.joinpath('export_mw8.csv').as_posix())

# %%
#Convert to DF and mask for plots

df = mw8_all.df()
mask = (~np.isnan(df['FRES'])  & (df.index < 340) & (df.index > 20) )

# %% [markdown]
# ###  Archie's  Law
# $$R_o = F*R_w $$
# $$R_o = \phi^{-m}*R_w $$
# ### Arp's Law in degrees Fahrenheit
# $$R_{w2} = R_{w1}\frac{T_1 + 6.77}{T_2 + 6.77}$$

# %%
ref_temp= 77
df['FRESc'] = df['FRES']*(df['TMP']+6.77)/(ref_temp + 6.77)

plt.scatter(df['FRES'][mask],df['FRESc'][mask],label='data',c='red',s=2,marker='o')
plt.plot(np.arange(1,25),np.arange(1,25),'k',label='one-to-one')
plt.legend()
plt.gca().set_aspect(1)
plt.xlabel('Original Fluid Res.')
plt.ylabel('Fluid Res. @ ref temp.');
plt.title('Original vs Corrected Fluid Resistiivty')
# Out:
# Text(0.5,1,'Original vs Corrected Fluid Resistiivty')

# %% [markdown]
# ### Import lithology data and WQ data

# %%
mwlith= pd.read_excel(auxdir.joinpath('Lith_MPWSP.xlsx'))
wellids = np.unique(mwlith['WellID'])

mwlith['topft'] = mwlith['Top_m']/.3048
mwlith['botft'] = mwlith['Bottom_m']/.3048

mask8 = mwlith['WellID']=='MW-8D'

# %%
df_lith = []
for d in df.index:
     df_lith.append(mwlith[mask8][((d>=mwlith[mask8]['topft']) & (d<mwlith[mask8]['botft']))]['Lith_Code_Orig'].values[0])

df['lith'] = df_lith
df_noclay = [True if x.find('C')==-1 else False for x in df['lith']]
df_SP = [True if x=='SP' else False for x in df['lith']]

df_noclaymask = np.logical_and(df_noclay, mask.values)
df_SPmask = np.logical_and(df_SP, mask.values)

# %% [markdown]
# ### Bulk Resistivity vs. Fluid Resistivity

# %%
f,ax=plt.subplots(1,figsize=(6,8))
ax.invert_yaxis()
plt.step(np.log10(df['RILD'][mask]),df.index[mask],label='Bulk Res.')
plt.step(np.log10(df['FRES'][mask]),df.index[mask],label='Fluid Res.')
plt.legend()
plt.ylabel('Depth (ft)')
plt.xlabel('Bulk Res. ($log_{10}(\Omega$-$m$))');
ax.set_aspect(1/50)
plt.title('MW-8 Bulk Resistivity log');

# %%
from scipy import stats
def x_y_regression(xin,yin,cin,msk=None,slpname='F'):
    if msk is None:
        x=xin
        y=yin
        c=cin
    else:
        x=xin[msk]
        y=yin[msk]
        c=cin[msk]
    slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
    plt.set_cmap('viridis_r')
    f,ax = plt.subplots(1,figsize=(7,4))
    plt.scatter(x,y,c=c)
    plt.plot(x,slope*x + intercept,'--k')
    plt.text(x.mean(),y.mean()*2,'{} = {:.2f} \n$R^2$ = {:.2f}'.format(slpname,slope,r_value**2))
    cb = plt.colorbar()
    cb.set_label('Depth (ft)', rotation=0)
    return f,ax

# %% [markdown]
# ### Applying Archie's Law

# %%
x = df['FRES']
y = df['RILD']
c = df.index
f,ax = x_y_regression(x,y,c,mask);
plt.title('MW-8: Fluid Resistivity vs RILD: \nAll values')
plt.xlabel('Fluid Res.  ($\Omega$-$m$)')
plt.ylabel('Bulk Res. ($\Omega$-$m$)')
plt.show();

f,ax = x_y_regression(x,y,c,df_SPmask);
plt.title('MW-8: Fluid Resistivity vs RILD: \nSP only')
plt.xlabel('Fluid Res.  ($\Omega$-$m$)')
plt.ylabel('Bulk Res. ($\Omega$-$m$)')
plt.show();
